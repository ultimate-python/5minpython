# %% [markdown]
# ![EP1.png](attachment:EP1.png)

# %% [markdown]
# # การใช้งาน Jupyter Notebook

# %% [markdown]
# คล้ายกับการทำงานกับเอกสาร โดยแบ่งเป็นส่วนย่อยๆ เป็นช่องที่เรียกว่า cell

# %% [markdown]
# วันนี้เราจะมาทำงานกับ cell ต่างๆ ที่ต้องรู้เพื่อเขียนโค้ดบรรทัดแรกของคุณ

# %% [markdown]
# # 1) คลิกเลือก cell ที่จะทำงานด้วย

# %% [markdown]
# cell ที่ถูกเลือกจะมีสัญลักษณ์แท่งสีฟ้าด้านหน้า

# %% [markdown]
# ![selected%20cell.png](attachment:selected%20cell.png)

# %% [markdown]
# # 2) เพิ่ม cell

# %% [markdown]
# จะเพิ่ม cell ด้านล่าง cell ที่ถูกเลือกอยู่

# %% [markdown]
# ![toolbar%20+.jpg](attachment:toolbar%20+.jpg)

# %% [markdown]
# # 3) พิมพ์คำสั่ง Python

# %% [markdown]
# คลิกเลือกส่วนเนื้อหาในกล่องสีเทา สังเกตสัญลักษณ์แท่งสีเขียวด้านหน้า

# %% [markdown]
# ![edit%20mode.png](attachment:edit%20mode.png)

# %% [markdown]
# เมื่อพิมพ์คำสั่งต่างๆ เสร็จแล้ว ให้คลิกที่ cell อื่นเพื่อออก หรือ run cell เพื่อแสดงผล

# %% [markdown]
# # 4) Run cell

# %% [markdown]
# ประมวลผลคำสั่ง หรือที่เรียกว่า รัน (Run) สำหรับ cell ที่เลือกอยู่ ณ ขณะนั้น

# %% [markdown]
# ![toolbar%20run.jpg](attachment:toolbar%20run.jpg)

# %% [markdown]
# # 5) ทดลอง Run cell ด้านล่าง

# %%
print('hello world')

# %% [markdown]
# # สรุป

# %% [markdown]
# ถ้าคุณสามารถทำตามทั้ง 5 ข้อในบทนี้ได้ ก็เท่ากับว่าคุณได้เขียนโค้ดบันทัดแรกของคุณเรียบร้อยแล้ว!

# %% [markdown]
# ถ้าบทเรียนนี้เป็นประโยชน์ อย่าลืมกดติดตาม และตั้งค่าเห็นก่อน เพจ [Ultimate Python](https://www.facebook.com/ultimatepython)

# %% [markdown]
# อย่าลืมสมัครสมาชิกบนเวปไซต์ และติดตาม [blog](https://www.ultimatepython.co/blog) ของเรา
