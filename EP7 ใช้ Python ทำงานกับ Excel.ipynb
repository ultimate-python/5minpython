# %% [markdown]
# ![EP7.png](attachment:EP7.png)

# %%
import pandas as pd

# %%
table = pd.read_excel("Sales.xlsx")
table
# Out:
#      Product  Period 1  Period 2
# 0  Product 1      6778      6760
# 1  Product 2      3634      6344

# %%
table = table.set_index("Product")
table
# Out:
#            Period 1  Period 2
# Product
# Product 1      6778      6760
# Product 2      3634      6344

# %%
new_column = table["Period 1"] + table["Period 2"]
new_column
# Out:
# Product
# Product 1    13538
# Product 2     9978
# dtype: int64

# %%
table["All Period"] = new_column
table
# Out:
#            Period 1  Period 2  All Period
# Product
# Product 1      6778      6760       13538
# Product 2      3634      6344        9978

# %%
new_row = table.loc["Product 1"] + table.loc["Product 2"]
new_row
# Out:
# Period 1      10412
# Period 2      13104
# All Period    23516
# dtype: int64

# %%
table.loc["All Product"] = new_row
table
# Out:
#              Period 1  Period 2  All Period
# Product
# Product 1        6778      6760       13538
# Product 2        3634      6344        9978
# All Product     10412     13104       23516

# %%
table.to_excel("New Sales.xlsx")
